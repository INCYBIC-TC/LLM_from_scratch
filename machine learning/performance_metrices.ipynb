# %% [markdown]
# # Performance Metrices

# %%
# sklearn.metrices provide built in function to calculate the common regression problems

# %% [markdown]
#   1. Mean Absolute error
#   2. Mean Squared error
#   3. Root mean square error
#   4. r2_score
#   5. Adjusted R2 score

# %%
# sample data 
y_true = [10, 15, 20, 25]
y_pred = [12, 14, 19, 27]

# %%
### 1.Mean absolute error
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_true,y_pred)
print("mean absolute error :",mae)
# Out:
# mean absolute error : 1.5

# %%
### 2.Mean Squared error 
from sklearn.metrics import mean_squared_error
mse =mean_squared_error(y_true,y_pred)
print("mean squared error :",mse)
# Out:
# mean squared error : 2.5

# %%
### 3.root mean square 
from sklearn.metrics import root_mean_squared_error
rmse = root_mean_squared_error(y_true,y_pred)
print("root mean squared error :",rmse)
# Out:
# root mean squared error : 1.5811388300841898

# %%
### 4.R square 
from sklearn.metrics import r2_score
r2 = r2_score(y_true,y_pred)
print("r2 score :",r2)
# Out:
# r2 score : 0.92

# %%
### 5.Adjusted r square 
from sklearn.metrics import r2_score
r2 =r2_score(y_true,y_pred)
# no.of samples
n =len(y_true)
#no of features
p=2

# apply the adjusted r2 square
adj_r2_square =1 -((1-r2) * (n-1))/(n-p-1)
print("adjusted r2 square :",adj_r2_square)
# Out:
# adjusted r2 square : 0.7600000000000001
